# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('training_data.csv')

# %%
df.head()
# Out:
#    PETROL (GHp/Lt)  DIESEL (GHp/Lt)  LPG (GHp/Kg)  KEROSENE (GHp/Lt)  \
# 0           453.30           497.50        470.03             401.96
# 1           481.86           492.21        470.03             401.96
# 2           481.86           492.21        490.44             401.96
# 3           481.86           492.21        503.04             401.96
# 4           481.86           492.21        513.88             401.96
#
#    MGO LOCAL (GHp/Lt)
# 0              403.75
# 1              403.75
# 2              403.75
# 3              403.75
# 4              403.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PETROL (GHp/Lt)     8578 non-null   float64
#  1   DIESEL (GHp/Lt)     8578 non-null   float64
#  2   LPG (GHp/Kg)        8578 non-null   float64
#  3   KEROSENE (GHp/Lt)   8578 non-null   float64
#  4   MGO LOCAL (GHp/Lt)  8578 non-null   float64
# dtypes: float64(5)
# memory usage: 335.2 KB

# %%
df.columns
# Out:
# Index(['PETROL (GHp/Lt)', 'DIESEL (GHp/Lt)', 'LPG (GHp/Kg)',
#        'KEROSENE (GHp/Lt)', 'MGO LOCAL (GHp/Lt)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PETROL (GHp/Lt)       0
# DIESEL (GHp/Lt)       0
# LPG (GHp/Kg)          0
# KEROSENE (GHp/Lt)     0
# MGO LOCAL (GHp/Lt)    0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['PETROL (GHp/Lt)'], kde=True, color='blue')
plt.title('Distribution of Petrol Prices')
plt.xlabel('Price(GHp/Lt)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
corr_matrix = df.corr()

# Identify the most relevant features for predicting 'Petrol Prices'
relevant_features = corr_matrix['PETROL (GHp/Lt)'].sort_values(ascending=False)
print(relevant_features)
# Out:
# PETROL (GHp/Lt)       1.000000
# DIESEL (GHp/Lt)       0.875404
# MGO LOCAL (GHp/Lt)    0.608277
# KEROSENE (GHp/Lt)     0.603722
# LPG (GHp/Kg)          0.600099
# Name: PETROL (GHp/Lt), dtype: float64

# %%
X = df.drop('PETROL (GHp/Lt)', axis=1)
y = df['PETROL (GHp/Lt)']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train various machine learning models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest Regressor": RandomForestRegressor(random_state=42),
    "Support Vector Regressor": SVR()
}

for model_name, model in models.items():
    # Train the model
    model.fit(X_train, y_train)
    
    # Make predictions on the testing set
    y_pred = model.predict(X_test)
    
    # Evaluate the performance of the model using mean squared error and R-squared
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"Model: {model_name}")
    print('Mean Squared Error:', mse)
    print('R-squared:', r2)
    print("="*30)
# Out:
# Model: Linear Regression
# Mean Squared Error: 10343.174368640135
# R-squared: 0.9739337129880564
# ==============================
# Model: Random Forest Regressor
# Mean Squared Error: 56553.825488886425
# R-squared: 0.8574762259363808
# ==============================
# Model: Support Vector Regressor
# Mean Squared Error: 270301.9162550793
# R-squared: 0.318800294970801
# ==============================

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a random forest regressor model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = rf_model.predict(X_test)

# Evaluate the performance of the model using mean squared error and R-squared
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 56553.825488886425
# R-squared: 0.8574762259363808

# %%
rf_model
# Out:
# RandomForestRegressor(random_state=42)

# %%
import joblib

# %%
joblib.dump(rf_model, 'random_forest_regressor_model_for_petrol.joblib')
# Out:
# ['random_forest_regressor_model_for_petrol.joblib']

# %%
predictions = rf_model.predict(X_test)

# %%
#predicted petrol price
predictions
# Out:
# array([537.0388, 436.6789, 533.5573, ..., 717.1518, 501.3249, 688.694 ])

# %%
#original petrol price
y_test
# Out:
# 1176    540.00
# 2124    439.90
# 3785    535.00
# 1864    442.00
# 33      501.17
#          ...
# 279     500.00
# 3909    652.65
# 4949    718.22
# 2571    493.88
# 5165    680.00
# Name: PETROL (GHp/Lt), Length: 2574, dtype: float64

# %%
plt.scatter(y_test,predictions)

# %%
##################

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Split the dataset into training and testing sets
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Train a linear regression model
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = lr_model.predict(X_test)

# Evaluate the performance of the model using mean squared error and R-squared
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 10343.174368640135
# R-squared: 0.9739337129880564

# %%
lr_model
# Out:
# LinearRegression()

# %%
#joblib.dump(lr_model, 'linear_regression_model_for_petrol.joblib')

# %%
predictions = lr_model.predict(X_test)

# %%
#predicted petrol price
predictions
# Out:
# array([536.5184503 , 449.68419089, 534.51220645, ..., 695.96643804,
#        507.33523255, 670.72911018])

# %%
#original petrol price
y_test
# Out:
# 1176    540.00
# 2124    439.90
# 3785    535.00
# 1864    442.00
# 33      501.17
#          ...
# 279     500.00
# 3909    652.65
# 4949    718.22
# 2571    493.88
# 5165    680.00
# Name: PETROL (GHp/Lt), Length: 2574, dtype: float64

# %%
plt.scatter(y_test,predictions)
