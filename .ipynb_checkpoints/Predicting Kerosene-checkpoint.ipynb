# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('training_data.csv')

# %%
df.head()
# Out:
#    PETROL (GHp/Lt)  DIESEL (GHp/Lt)  LPG (GHp/Kg)  KEROSENE (GHp/Lt)  \
# 0           453.30           497.50        470.03             401.96
# 1           481.86           492.21        470.03             401.96
# 2           481.86           492.21        490.44             401.96
# 3           481.86           492.21        503.04             401.96
# 4           481.86           492.21        513.88             401.96
#
#    MGO LOCAL (GHp/Lt)
# 0              403.75
# 1              403.75
# 2              403.75
# 3              403.75
# 4              403.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PETROL (GHp/Lt)     8578 non-null   float64
#  1   DIESEL (GHp/Lt)     8578 non-null   float64
#  2   LPG (GHp/Kg)        8578 non-null   float64
#  3   KEROSENE (GHp/Lt)   8578 non-null   float64
#  4   MGO LOCAL (GHp/Lt)  8578 non-null   float64
# dtypes: float64(5)
# memory usage: 335.2 KB

# %%
df.columns
# Out:
# Index(['PETROL (GHp/Lt)', 'DIESEL (GHp/Lt)', 'LPG (GHp/Kg)',
#        'KEROSENE (GHp/Lt)', 'MGO LOCAL (GHp/Lt)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PETROL (GHp/Lt)       0
# DIESEL (GHp/Lt)       0
# LPG (GHp/Kg)          0
# KEROSENE (GHp/Lt)     0
# MGO LOCAL (GHp/Lt)    0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['KEROSENE (GHp/Lt)'], kde=True, color='blue')
plt.title('Distribution of Kerosene Prices')
plt.xlabel('Price(GHp/Lt)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
corr_matrix = df.corr()

# Identify the most relevant features for predicting 'Kerosene Prices'
relevant_features = corr_matrix['KEROSENE (GHp/Lt)'].sort_values(ascending=False)
print(relevant_features)
# Out:
# KEROSENE (GHp/Lt)     1.000000
# MGO LOCAL (GHp/Lt)    0.917788
# LPG (GHp/Kg)          0.853181
# DIESEL (GHp/Lt)       0.709842
# PETROL (GHp/Lt)       0.603722
# Name: KEROSENE (GHp/Lt), dtype: float64

# %%
X = df.drop('KEROSENE (GHp/Lt)', axis=1)
y = df['KEROSENE (GHp/Lt)']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a random forest regressor model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = rf_model.predict(X_test)

# Evaluate the performance of the model using mean squared error and R-squared
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 16249.732607934115
# R-squared: 0.9276720274119555

# %%
rf_model
# Out:
# RandomForestRegressor(random_state=42)

# %%
import joblib

# %%
joblib.dump(rf_model, 'random_forest_regressor_model_for_kerosene.joblib')
# Out:
# ['random_forest_regressor_model_for_kerosene.joblib']

# %%
predictions = rf_model.predict(X_test)

# %%
#predicted kerosene price
predictions
# Out:
# array([454.68647619, 363.1207    , 461.7934    , ..., 663.8926    ,
#        434.5994    , 539.2834    ])

# %%
#original kerosene price
y_test
# Out:
# 1176    480.00
# 2124    349.88
# 3785    457.13
# 1864    533.63
# 33      437.69
#          ...
# 279     491.00
# 3909    605.00
# 4949    666.00
# 2571    420.00
# 5165    496.00
# Name: KEROSENE (GHp/Lt), Length: 2574, dtype: float64

# %%
plt.scatter(y_test,predictions)
