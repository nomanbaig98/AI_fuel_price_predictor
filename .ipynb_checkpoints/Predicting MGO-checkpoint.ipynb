# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('train_mgo.csv')

# %%
df.head()
# Out:
#    KEROSENE (GHp/Lt)  LPG (GHp/Kg)  PETROL (GHp/Lt)  DIESEL (GHp/Lt)  \
# 0             639.13        838.98            780.0            682.0
# 1             750.00        937.65            798.0            796.0
# 2             830.00        972.98            940.0            938.0
# 3            1108.13       1157.98           1120.0           1255.0
# 4            1199.30       1087.96           1180.0           1236.0
#
#    MGO LOCAL (GHp/Lt)
# 0              768.23
# 1              888.73
# 2              903.04
# 3             1063.78
# 4             1037.96

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   KEROSENE (GHp/Lt)   19 non-null     float64
#  1   LPG (GHp/Kg)        19 non-null     float64
#  2   PETROL (GHp/Lt)     19 non-null     float64
#  3   DIESEL (GHp/Lt)     19 non-null     float64
#  4   MGO LOCAL (GHp/Lt)  19 non-null     float64
# dtypes: float64(5)
# memory usage: 888.0 bytes

# %%
df.columns
# Out:
# Index(['KEROSENE (GHp/Lt)', 'LPG (GHp/Kg)', 'PETROL (GHp/Lt)',
#        'DIESEL (GHp/Lt)', 'MGO LOCAL (GHp/Lt)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# KEROSENE (GHp/Lt)     0
# LPG (GHp/Kg)          0
# PETROL (GHp/Lt)       0
# DIESEL (GHp/Lt)       0
# MGO LOCAL (GHp/Lt)    0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['MGO LOCAL (GHp/Lt)'], kde=True, color='blue')
plt.title('Distribution of MGO Prices')
plt.xlabel('Price(GHp/Lt)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
corr_matrix = df.corr()

# Identify the most relevant features for predicting 'MGO Prices'
relevant_features = corr_matrix['MGO LOCAL (GHp/Lt)'].sort_values(ascending=False)
print(relevant_features)
# Out:
# MGO LOCAL (GHp/Lt)    1.000000
# KEROSENE (GHp/Lt)     0.856179
# DIESEL (GHp/Lt)       0.839264
# PETROL (GHp/Lt)       0.744731
# LPG (GHp/Kg)          0.685674
# Name: MGO LOCAL (GHp/Lt), dtype: float64

# %%
X = df.drop('MGO LOCAL (GHp/Lt)', axis=1)
y = df['MGO LOCAL (GHp/Lt)']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Train a random forest regressor model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = rf_model.predict(X_test)

# Evaluate the performance of the model using mean squared error and R-squared
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 14249.809371199826
# R-squared: 0.347460030206716

# %%
rf_model
# Out:
# RandomForestRegressor(random_state=42)

# %%
import joblib

# %%
joblib.dump(rf_model, 'random_forest_regressor_model_for_mgo.joblib')
# Out:
# ['random_forest_regressor_model_for_mgo.joblib']

# %%
predictions = rf_model.predict(X_test)

# %%
#predicted mgo price
predictions
# Out:
# array([ 935.3444, 1087.7048])

# %%
#original mgo price
y_test
# Out:
# 0     768.23
# 5    1063.78
# Name: MGO LOCAL (GHp/Lt), dtype: float64

# %%
plt.scatter(y_test,predictions)
