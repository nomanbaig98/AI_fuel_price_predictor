# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('training_data.csv')

# %%
df.head()
# Out:
#    PETROL (GHp/Lt)  DIESEL (GHp/Lt)  LPG (GHp/Kg)  KEROSENE (GHp/Lt)  \
# 0           453.30           497.50        470.03             401.96
# 1           481.86           492.21        470.03             401.96
# 2           481.86           492.21        490.44             401.96
# 3           481.86           492.21        503.04             401.96
# 4           481.86           492.21        513.88             401.96
#
#    MGO LOCAL (GHp/Lt)
# 0              403.75
# 1              403.75
# 2              403.75
# 3              403.75
# 4              403.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PETROL (GHp/Lt)     8578 non-null   float64
#  1   DIESEL (GHp/Lt)     8578 non-null   float64
#  2   LPG (GHp/Kg)        8578 non-null   float64
#  3   KEROSENE (GHp/Lt)   8578 non-null   float64
#  4   MGO LOCAL (GHp/Lt)  8578 non-null   float64
# dtypes: float64(5)
# memory usage: 335.2 KB

# %%
df.columns
# Out:
# Index(['PETROL (GHp/Lt)', 'DIESEL (GHp/Lt)', 'LPG (GHp/Kg)',
#        'KEROSENE (GHp/Lt)', 'MGO LOCAL (GHp/Lt)'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# PETROL (GHp/Lt)       0
# DIESEL (GHp/Lt)       0
# LPG (GHp/Kg)          0
# KEROSENE (GHp/Lt)     0
# MGO LOCAL (GHp/Lt)    0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['MGO LOCAL (GHp/Lt)'], kde=True, color='blue')
plt.title('Distribution of MGO Prices')
plt.xlabel('Price(GHp/Lt)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
corr_matrix = df.corr()

# Identify the most relevant features for predicting 'MGO Prices'
relevant_features = corr_matrix['MGO LOCAL (GHp/Lt)'].sort_values(ascending=False)
print(relevant_features)
# Out:
# MGO LOCAL (GHp/Lt)    1.000000
# KEROSENE (GHp/Lt)     0.917788
# LPG (GHp/Kg)          0.860091
# DIESEL (GHp/Lt)       0.716814
# PETROL (GHp/Lt)       0.608277
# Name: MGO LOCAL (GHp/Lt), dtype: float64

# %%
X = df.drop('MGO LOCAL (GHp/Lt)', axis=1)
y = df['MGO LOCAL (GHp/Lt)']

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score



# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train a random forest regressor model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Make predictions on the testing set
y_pred = rf_model.predict(X_test)

# Evaluate the performance of the model using mean squared error and R-squared
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 11478.517365731153
# R-squared: 0.9429396730989361

# %%
rf_model
# Out:
# RandomForestRegressor(random_state=42)

# %%
import joblib

# %%
joblib.dump(rf_model, 'random_forest_regressor_model_for_mgo.joblib')
# Out:
# ['random_forest_regressor_model_for_mgo.joblib']

# %%
predictions = rf_model.predict(X_test)

# %%
#predicted mgo price
predictions
# Out:
# array([455.1929, 332.5533, 434.5194, ..., 545.0594, 418.4899, 514.1802])

# %%
#original mgo price
y_test
# Out:
# 1176    470.00
# 2124    334.18
# 3785    444.13
# 1864    418.93
# 33      428.30
#          ...
# 279     430.69
# 3909    566.00
# 4949    544.12
# 2571    400.00
# 5165    532.91
# Name: MGO LOCAL (GHp/Lt), Length: 2574, dtype: float64

# %%
plt.scatter(y_test,predictions)
